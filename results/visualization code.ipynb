# %%
####math regular
import numpy as np
import matplotlib.pyplot as plt


#gpt4 mv weighted
x = [1, 3, 5, 7, 9]
y_g_sm_1 = [94.9, 94.9, 94.9, 94.9, 94.9]
y_g_sm_32 = [90.01, 91.37, 91.20, 91.37, 91.70]
y_g_sm_64 = [92.70, 93.43, 94.52, 94.16, 94.53]


plt.figure(figsize=(4,4))
plt.title('gpt-4 + SEAS')
plt.xlabel('voting time')
plt.ylabel('overall accuracy')
plt.plot(x, y_g_sm_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_g_sm_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.plot(x, y_g_sm_64, label = 'bs=64', marker = 'h', markersize = 4,  color = 'y')
plt.legend(loc = 'lower right')

# %%
####Boolq adaptive
import numpy as np
import matplotlib.pyplot as plt
#chatgpt mv weighted
x = [1, 3, 5, 7]
y_c_m_1 = [86.83,  86.83, 86.83, 86.83]
y_c_sm_32 = [75.31, 79.375, 80.0, 80.3125]


#gpt4 mv weighted
x = [1, 3, 5, 7]
y_g_sm_1 = [90.625, 90.625, 90.625, 90.625]
y_g_sm_32 = [88.125, 90.3125, 90.9375, 90.9375]
y_g_sm_64 = [74.375, 87.8125, 88.75, 89.0625]


plt.figure(figsize=(4,4))
plt.title('gpt-3.5-turbo + SEAS')
plt.xlabel('voting time')
plt.ylabel('overall accuracy')
plt.plot(x, y_c_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_c_sm_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.legend(loc = 'lower right')

plt.figure(figsize=(4,4))
plt.title('gpt-4 + SEAS')
plt.xlabel('voting time')
plt.ylabel('overall accuracy')
plt.plot(x, y_g_sm_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_g_sm_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.plot(x, y_g_sm_64, label = 'bs=64', marker = 'h', markersize = 4,  color = 'y')
plt.legend(loc = 'lower right')


# Boolq tokens chatgpt
x = [1, 3, 5, 7]
y_boolq_m_1 = [384946, 384946, 384946, 384946]
y_boolq_mc_32 = [56346, 112780, 123623, 127807]

# Boolq tokens gpt4
y_boolq_mg_32 = [56346, 105419, 107957, 108490]
y_boolq_mg_64 = [51046, 113933, 124424, 126337]


plt.figure(figsize=(4,4))
plt.title('Boolq dataset token comparison with gpt-3.5-turbo + SEAS')
plt.xlabel('voting time')
plt.ylabel('total token numbers')
plt.plot(x, y_boolq_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_boolq_mc_32, label = 'bs=32', marker = 'o', markersize = 4,  color = 'b')
plt.legend(loc = 'lower right')

plt.figure(figsize=(4,4))
plt.title('Boolq dataset token comparison with gpt-4 + SEAS')
plt.xlabel('voting time')
plt.ylabel('total token numbers')
plt.plot(x, y_boolq_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_boolq_mg_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.plot(x, y_boolq_mg_64, label = 'bs=64', marker = 'h', markersize = 4,  color = 'y')
plt.legend(loc = 'lower right')

# %%
####QQP adaptive
import numpy as np
import matplotlib.pyplot as plt
#chatgpt mv weighted
x = [1, 3, 5, 7]
y_c_m_1 = [81.875, 81.875, 81.875, 81.875]
y_c_sm_32 = [75.0, 75.3125, 76.25, 78.125]


#gpt4 mv weighted
x = [1, 3, 5, 7]
y_g_m_1 = [87.2, 87.2, 87.2, 87.2]
y_g_sm_32 = [88.125, 88.4375, 88.4375, 88.4375]
y_g_sm_64 = [85.9375, 87.8125, 87.8125, 87.8125]
y_g_sm_160 = [85.3125, 86.25,  86.5625, 87.5]

plt.figure(figsize=(4,4))
plt.title('gpt-3.5-turbo + SEAS')
plt.xlabel('voting time')
plt.ylabel('overall accuracy')
plt.plot(x, y_c_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_c_sm_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.legend(loc = 'lower right')

plt.figure(figsize=(4,4))
plt.title('gpt-4 + SEAS')
plt.xlabel('voting time')
plt.ylabel('overall accuracy')
plt.plot(x, y_g_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_g_sm_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.plot(x, y_g_sm_64, label = 'bs=64', marker = 'h', markersize = 4,  color = 'y')
plt.plot(x, y_g_sm_160, label = 'bs=160', marker = 'h', markersize = 4,  color = 'b')
plt.legend(loc = 'lower right')


# Boolq tokens chatgpt
x = [1, 3, 5, 7]
y_boolq_m_1 = [171401, 171401, 171401, 171401]
y_boolq_mc_32 = [17641, 38148, 50514, 60133]

# Boolq tokens gpt4
y_boolq_mg_32 = [17641, 31900, 33170, 33253]
y_boolq_mg_64 = [15161, 29058, 29509, 29581]
y_boolq_mg_160 = [13673, 27987, 29765, 30396]

plt.figure(figsize=(4,4))
plt.title('qqp dataset token comparison with gpt-3.5-turbo + SEAS')
plt.xlabel('voting time')
plt.ylabel('total token numbers')
plt.plot(x, y_boolq_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_boolq_mc_32, label = 'bs=32', marker = 'o', markersize = 4,  color = 'b')
plt.legend(loc = 'lower right')

plt.figure(figsize=(4,4))
plt.title('qqp dataset token comparison with gpt-4 + SEAS')
plt.xlabel('voting time')
plt.ylabel('total token numbers')
plt.plot(x, y_boolq_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_boolq_mg_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.plot(x, y_boolq_mg_64, label = 'bs=64', marker = 'h', markersize = 4,  color = 'y')
plt.plot(x, y_boolq_mg_160, label = 'bs=160', marker = 'h', markersize = 4,  color = 'b')
plt.legend(loc = 'lower right')

# %%
####RTE adaptive
import numpy as np
import matplotlib.pyplot as plt
#chatgpt mv weighted
x = [1, 3, 5, 7]
y_c_m_1 = [80.67, 80.67,80.67,80.67]
y_c_sm_32 = [77.695, 78.43, 78.06,77.69]


#gpt4 mv weighted
x = [1, 3, 5, 7]
y_g_sm_1 = [91.45, 91.45, 91.45, 91.45]
y_g_sm_32 = [88.10, 90.33, 91.078,  90.70]
y_g_sm_64 = [79.553, 85.50, 84.75, 84.75]
y_g_sm_160 = [71.747, 76.579, 76.95, 76.579]
##diele! fenxi!
plt.figure(figsize=(4,4))
plt.title('gpt-3.5-turbo + SEAS')
plt.xlabel('voting time')
plt.ylabel('overall accuracy')
plt.plot(x, y_c_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_c_sm_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.legend(loc = 'lower right')

plt.figure(figsize=(4,4))
plt.title('gpt-4 + SEAS')
plt.xlabel('voting time')
plt.ylabel('overall accuracy')
plt.plot(x, y_g_sm_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_g_sm_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.plot(x, y_g_sm_64, label = 'bs=64', marker = 'h', markersize = 4,  color = 'y')
plt.plot(x, y_g_sm_160, label = 'bs=160', marker = 'h', markersize = 4,  color = 'b')
plt.legend(loc = 'lower right')


# RTE tokens chatgpt
x = [1, 3, 5, 7]
y_boolq_m_1 = [158270, 158270, 158270, 158270]
y_boolq_mc_32 = [25921, 54000, 62838, 67191]

# RTE tokens gpt4
y_boolq_mg_32 = [25921, 47807, 48693, 48970]
y_boolq_mg_64 = [23366, 48647, 51420, 51541]
y_boolq_mg_160 = [21833, 51048, 56633, 57004]

plt.figure(figsize=(4,4))
plt.title('rte dataset token comparison with gpt-3.5-turbo + SEAS')
plt.xlabel('voting time')
plt.ylabel('total token numbers')
plt.plot(x, y_boolq_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_boolq_mc_32, label = 'bs=32', marker = 'o', markersize = 4,  color = 'b')
plt.legend(loc = 'lower right')

plt.figure(figsize=(4,4))
plt.title('rte dataset token comparison with gpt-4 + SEAS')
plt.xlabel('voting time')
plt.ylabel('total token numbers')
plt.plot(x, y_boolq_m_1, label = 'bs=1', linestyle = '--', color = 'k')
plt.plot(x, y_boolq_mg_32, label = 'bs=32', marker = 'D', markersize = 4,  color = 'g')
plt.plot(x, y_boolq_mg_64, label = 'bs=64', marker = 'h', markersize = 4,  color = 'y')
plt.plot(x, y_boolq_mg_160, label = 'bs=160', marker = 'h', markersize = 4,  color = 'b')
plt.legend(loc = 'lower right')
